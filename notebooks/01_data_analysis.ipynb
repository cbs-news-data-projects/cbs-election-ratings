# %% [markdown]
# # [Analysis name]
#
# **Question:** One sentence. What this notebook answers.
# **Source:** [Dataset name], [publisher]. [URL]
# **Local path:** `data/raw/[filename]`
# **Pulled:** YYYY-MM-DD
# **Record range:** YYYY-MM-DD to YYYY-MM-DD
# **Refresh:** [cadence, or "one-time pull"]
# **Known limits:** One line. Suppressed cells, revised figures, coverage gaps.
#
# Load from `data/raw/` (immutable). Write results to `data/processed/`.
# Charts here are for exploration. Export to Datawrapper for anything published.

# %%
import pandas as pd

from config import RAW_DATA_DIR, PROCESSED_DATA_DIR
from utils import quick_info, clean_column_names, data_fact_check, quick_export_for_web

# %%
# Load
# df = pd.read_csv(RAW_DATA_DIR / "source.csv")
# df = clean_column_names(df)
# quick_info(df)

# %%
# Analyze

# %%
# Fact-check, then export
# data_fact_check(df)
# quick_export_for_web(df, "results", format_type="csv")
